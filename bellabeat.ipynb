# %% [markdown]
# <a href="https://colab.research.google.com/github/TutuBraz/bellabeat-custumer-behavior/blob/main/bellabeat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Preparar.

# %%
#manipulacao
import pandas as pd

#datas
from datetime import datetime

#vizualizacao
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Funcao para verificaar a integridade dos dados
def Integridade(dataset, col='Id', col2='Time'):
  print(f'Quantidade de usuários: {len(dataset[col].unique())}')
  print(f'Valors duplicados: {dataset.duplicated().sum()}')
  print(f'Valores ausentes:{dataset.isnull().sum()}')

# %%
#resumo das atividades dos usúarios
day_activity = pd.read_csv('/content/dailyActivity_merged.csv')
Integridade(day_activity)
# Out:
# Quantidade de usuários: 33
# Valors duplicados: 0
# Valores ausentes:Id                          0
# ActivityDate                0
# TotalSteps                  0
# TotalDistance               0
# TrackerDistance             0
# LoggedActivitiesDistance    0
# VeryActiveDistance          0
# ModeratelyActiveDistance    0
# LightActiveDistance         0
# SedentaryActiveDistance     0
# VeryActiveMinutes           0
# FairlyActiveMinutes         0
# LightlyActiveMinutes        0
# SedentaryMinutes            0
# Calories                    0
# dtype: int64

# %%
day_activity.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    4/12/2016       13162           8.50             8.50
# 1  1503960366    4/13/2016       10735           6.97             6.97
# 2  1503960366    4/14/2016       10460           6.74             6.74
# 3  1503960366    4/15/2016        9762           6.28             6.28
# 4  1503960366    4/16/2016       12669           8.16             8.16
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                1.88                      0.55
# 1                       0.0                1.57                      0.69
# 2                       0.0                2.44                      0.40
# 3                       0.0                2.14                      1.26
# 4                       0.0                2.71                      0.41
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                 6.06                      0.0                 25
# 1                 4.71                      0.0                 21
# 2                 3.91                      0.0                 30
# 3                 2.83                      0.0                 29
# 4                 5.04                      0.0                 36
#
#    FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories
# 0                   13                   328               728      1985
# 1                   19                   217               776      1797
# 2                   11                   181              1218      1776
# 3                   34                   209               726      1745
# 4                   10                   221               773      1863

# %%
#intensidade dos exercicios
day_intensities = pd.read_csv('/content/dailyIntensities_merged.csv')
Integridade(day_intensities)
# Out:
# Quantidade de usuários: 33
# Valors duplicados: 0
# Valores ausentes:Id                          0
# ActivityDay                 0
# SedentaryMinutes            0
# LightlyActiveMinutes        0
# FairlyActiveMinutes         0
# VeryActiveMinutes           0
# SedentaryActiveDistance     0
# LightActiveDistance         0
# ModeratelyActiveDistance    0
# VeryActiveDistance          0
# dtype: int64

# %%
day_intensities.head()
# Out:
#            Id ActivityDay  SedentaryMinutes  LightlyActiveMinutes  \
# 0  1503960366   4/12/2016               728                   328
# 1  1503960366   4/13/2016               776                   217
# 2  1503960366   4/14/2016              1218                   181
# 3  1503960366   4/15/2016               726                   209
# 4  1503960366   4/16/2016               773                   221
#
#    FairlyActiveMinutes  VeryActiveMinutes  SedentaryActiveDistance  \
# 0                   13                 25                      0.0
# 1                   19                 21                      0.0
# 2                   11                 30                      0.0
# 3                   34                 29                      0.0
# 4                   10                 36                      0.0
#
#    LightActiveDistance  ModeratelyActiveDistance  VeryActiveDistance
# 0                 6.06                      0.55                1.88
# 1                 4.71                      0.69                1.57
# 2                 3.91                      0.40                2.44
# 3                 2.83                      1.26                2.14
# 4                 5.04                      0.41                2.71

# %%
#Gasto energético
mets = pd.read_csv('/content/minuteMETsNarrow_merged.csv')
Integridade(mets)
# Out:
# Quantidade de usuários: 33
# Valors duplicados: 0
# Valores ausentes:Id                0
# ActivityMinute    0
# METs              0
# dtype: int64

# %%
mets.head()
# Out:
#            Id         ActivityMinute  METs
# 0  1503960366  4/12/2016 12:00:00 AM    10
# 1  1503960366  4/12/2016 12:01:00 AM    10
# 2  1503960366  4/12/2016 12:02:00 AM    10
# 3  1503960366  4/12/2016 12:03:00 AM    10
# 4  1503960366  4/12/2016 12:04:00 AM    10

# %%
#minutos dormidos por dia
sleep_day =pd.read_csv('/content/sleepDay_merged.csv')
Integridade(sleep_day)
# Out:
# Quantidade de usuários: 24
# Valors duplicados: 3
# Valores ausentes:Id                    0
# SleepDay              0
# TotalSleepRecords     0
# TotalMinutesAsleep    0
# TotalTimeInBed        0
# dtype: int64

# %%
sleep_day.head()
# Out:
#            Id               SleepDay  TotalSleepRecords  TotalMinutesAsleep  \
# 0  1503960366  4/12/2016 12:00:00 AM                  1                 327
# 1  1503960366  4/13/2016 12:00:00 AM                  2                 384
# 2  1503960366  4/15/2016 12:00:00 AM                  1                 412
# 3  1503960366  4/16/2016 12:00:00 AM                  2                 340
# 4  1503960366  4/17/2016 12:00:00 AM                  1                 700
#
#    TotalTimeInBed
# 0             346
# 1             407
# 2             442
# 3             367
# 4             712

# %% [markdown]
# #Processar.

# %%
#Removendo duplicatas do dataset sleep_day
sleep_day = sleep_day.drop_duplicates()

#Verificando a integridade
Integridade(sleep_day)
# Out:
# Quantidade de usuários: 24
# Valors duplicados: 0
# Valores ausentes:Id                    0
# SleepDay              0
# TotalSleepRecords     0
# TotalMinutesAsleep    0
# TotalTimeInBed        0
# dtype: int64

# %%
def DiasSemana(dataset, col):
  #transformando a coluna para tipo date
  dataset.ActivityDate = pd.to_datetime(dataset[col], format="%m/%d/%Y")
  
  #Criando coluna dias da semana
  dia_semana = pd.to_datetime(dataset[col]).dt.strftime('%A')

  #Inserir dia da semana como uma nova coluna no dataframe
  dataset.insert(2, 'dia_semana', dia_semana)

  return dataset.head()

# %%
DiasSemana(day_activity, 'ActivityDate')
# Out:
#            Id ActivityDate dia_semana  TotalSteps  TotalDistance  \
# 0  1503960366   2016-04-12    Tuesday       13162           8.50
# 1  1503960366   2016-04-13  Wednesday       10735           6.97
# 2  1503960366   2016-04-14   Thursday       10460           6.74
# 3  1503960366   2016-04-15     Friday        9762           6.28
# 4  1503960366   2016-04-16   Saturday       12669           8.16
#
#    TrackerDistance  LoggedActivitiesDistance  VeryActiveDistance  \
# 0             8.50                       0.0                1.88
# 1             6.97                       0.0                1.57
# 2             6.74                       0.0                2.44
# 3             6.28                       0.0                2.14
# 4             8.16                       0.0                2.71
#
#    ModeratelyActiveDistance  LightActiveDistance  SedentaryActiveDistance  \
# 0                      0.55                 6.06                      0.0
# 1                      0.69                 4.71                      0.0
# 2                      0.40                 3.91                      0.0
# 3                      1.26                 2.83                      0.0
# 4                      0.41                 5.04                      0.0
#
#    VeryActiveMinutes  FairlyActiveMinutes  LightlyActiveMinutes  \
# 0                 25                   13                   328
# 1                 21                   19                   217
# 2                 30                   11                   181
# 3                 29                   34                   209
# 4                 36                   10                   221
#
#    SedentaryMinutes  Calories
# 0               728      1985
# 1               776      1797
# 2              1218      1776
# 3               726      1745
# 4               773      1863

# %%
DiasSemana(day_intensities, "ActivityDay")
# Out:
# <ipython-input-259-733d16e72ccc>:3: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   dataset.ActivityDate = pd.to_datetime(dataset[col], format="%m/%d/%Y")
#            Id ActivityDay dia_semana  SedentaryMinutes  LightlyActiveMinutes  \
# 0  1503960366   4/12/2016    Tuesday               728                   328
# 1  1503960366   4/13/2016  Wednesday               776                   217
# 2  1503960366   4/14/2016   Thursday              1218                   181
# 3  1503960366   4/15/2016     Friday               726                   209
# 4  1503960366   4/16/2016   Saturday               773                   221
#
#    FairlyActiveMinutes  VeryActiveMinutes  SedentaryActiveDistance  \
# 0                   13                 25                      0.0
# 1                   19                 21                      0.0
# 2                   11                 30                      0.0
# 3                   34                 29                      0.0
# 4                   10                 36                      0.0
#
#    LightActiveDistance  ModeratelyActiveDistance  VeryActiveDistance
# 0                 6.06                      0.55                1.88
# 1                 4.71                      0.69                1.57
# 2                 3.91                      0.40                2.44
# 3                 2.83                      1.26                2.14
# 4                 5.04                      0.41                2.71

# %%
#Funcao para transformar o formato de 12 horas e 24 horas
def convert24(str1): 
    if str1[-2:] == "AM" and str1[:2] == "12": 
        return "00" + str1[2:-2] 
          
    elif str1[-2:] == "AM": 
        return str1[:-2] 
    
    elif str1[-2:] == "PM" and str1[:2] == "12": 
        return str1[:-2] 
          
    else: 
        if ':' not in str1[:2]:
          return str(int(str1[:2]) + 12) + str1[2:8]
        
        else:
          hora =  str(int(str1[:1]) + 12) + str1[2:8] 
          return hora[:2]+':'+hora[2:]

def separa(df, col):
  df['data'], df['hora'] = df[col].str.split(' ', 1).str

# %%
#Criadno colunas data e hora
separa(mets, 'ActivityMinute')
separa(sleep_day, 'SleepDay')

#Aplicando a função em todas as linhas
mets['hora'] = mets['hora'].apply(convert24)
sleep_day['hora'] = sleep_day['hora'].apply(convert24)

#criando coluna dias da semana
DiasSemana(mets, 'data')
DiasSemana(sleep_day, 'data')

#removendo coluna
mets.drop(['ActivityMinute', 'Id'], axis=1, inplace = True)
sleep_day.drop(['SleepDay', 'Id'], axis=1, inplace = True)
day_activity.drop(['Id'], axis=1, inplace = True)
day_intensities.drop(['Id'], axis=1, inplace = True)



#reorganizando as colunas
mets = mets[['data','dia_semana' ,'hora','METs']]
sleep_day = sleep_day[['data','dia_semana','TotalSleepRecords', 'TotalMinutesAsleep',	'TotalTimeInBed']]
# Out:
# <ipython-input-262-145468d4bff7>:21: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   df['data'], df['hora'] = df[col].str.split(' ', 1).str
# <ipython-input-259-733d16e72ccc>:3: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   dataset.ActivityDate = pd.to_datetime(dataset[col], format="%m/%d/%Y")

# %% [markdown]
# #Analisar.

# %%
sleep_day['JustBed'] = sleep_day.TotalTimeInBed - sleep_day.TotalMinutesAsleep

# %%
sleep_day.head()
# Out:
#         data dia_semana  TotalSleepRecords  TotalMinutesAsleep  \
# 0  4/12/2016    Tuesday                  1                 327
# 1  4/13/2016  Wednesday                  2                 384
# 2  4/15/2016     Friday                  1                 412
# 3  4/16/2016   Saturday                  2                 340
# 4  4/17/2016     Sunday                  1                 700
#
#    TotalTimeInBed  JustBed
# 0             346       19
# 1             407       23
# 2             442       30
# 3             367       27
# 4             712       12

# %%
sleep_day.describe()
# Out:
#        TotalSleepRecords  TotalMinutesAsleep  TotalTimeInBed     JustBed
# count         410.000000          410.000000      410.000000  410.000000
# mean            1.119512          419.173171      458.482927   39.309756
# std             0.346636          118.635918      127.455140   46.710932
# min             1.000000           58.000000       61.000000    0.000000
# 25%             1.000000          361.000000      403.750000   17.000000
# 50%             1.000000          432.500000      463.000000   25.500000
# 75%             1.000000          490.000000      526.000000   40.000000
# max             3.000000          796.000000      961.000000  371.000000

# %%
#mediana  
sleep_day.median()
# Out:
# <ipython-input-340-1d90f82587b0>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   sleep_day.median()
# TotalSleepRecords       1.0
# TotalMinutesAsleep    432.5
# TotalTimeInBed        463.0
# JustBed                25.5
# dtype: float64

# %%
sns.set(style='whitegrid')

fig,axes = plt.subplots(3,1, figsize=(16,10))

sns.boxplot(x='TotalMinutesAsleep', y='dia_semana', data = sleep_day,
            ax = axes[0], order = ['Sunday','Monday', 'Tuesday', 'Wednesday','Thursday','Friday','Saturday'])

sns.boxplot(x='TotalTimeInBed', y='dia_semana', data = sleep_day,
            ax = axes[1],order = ['Sunday','Monday', 'Tuesday', 'Wednesday','Thursday','Friday','Saturday'])

sns.boxplot(x='JustBed', y='dia_semana', data = sleep_day,
            ax = axes[2],order = ['Sunday','Monday', 'Tuesday', 'Wednesday','Thursday','Friday','Saturday'])


fig.tight_layout()
plt.show()
